# %% [markdown]
# # App 1: Geometry Game

# %%
# Objects
a = 4
b = 5
c = [6,7,8] # the list is an object and is made of other objects

d = 'Hi'
'Hello World'

def area(x):
    return x**2 # the function is an object and is given a name/identifier


area(3)
# Out:
# 9

# %% [markdown]
# The 8 elements of the python programming language:
#
# 1. Objects
# 2. Identifiers
# 3. Operators
# 4. Delimiters
# 5. Keywords
# 6. Comments
# 7. Blank Lines
# 8. White space
# 9. Indentation
#
# - Objects ---> occupy space in memory
#
# - a,b,c,d ---> are **identifiers**
#
# - 4, 5, [6,7] ---> are Objects
#
# <u>**The function definition is an object**</u>
#
# ```
# def area(x):
#     return x**2
# ```
#
# - area ---> it is an identifier, names of functions i create
#
# - `x` ---> is an identifier
#
# - `2` ---> is an object
#
# - in `area(3)` ---> 3 is an object and the output of that is going to be `9` ---> `9` is also an object
#
# <u>**Operators**</u>
#
# - in this example we have the power oeprator `**`
#
# <u>**Delimiters**</u>
#
# - in this example `,`, `"`, `( )`, `[]`
#
# <u>**Keywords**</u>
#
# - Not objects or identifiers
# - They are spacial commands to denote the start or end of a function
#
# <u>**Comments**</u>
#
# - `#`
#
# <u>**Blank lines**</u>
#
# <u>**White space**</u>
#
# <u>**Indentation**</u>
#
# - to denote the dependence of a block of code
# - part of the pytohn syntax

# %%
inty = 5
listy = [6,7]

stringy = 'Hi'

import folium
azores = folium.folium.Map(location = (33.8938, 35.5018),
                            zoom_start = 8)

type(inty), type(listy), type(stringy), type(azores)
# Out:
# (int, list, str, folium.folium.Map)

# %%
# Saving the output of folium Map in an HTML file
azores.save("MapOutput.html")
azores
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
folium.__file__ # this is the library path in my local machine
# Out:
# 'C:\\Users\\Ahmad Sidaoui\\AppData\\Roaming\\Python\\Python311\\site-packages\\folium\\__init__.py'

# %% [markdown]
# <u>**Compound object**</u>
#
# ```
# folium.folium.Map(location = (38, -27),
#                             zoom_start = 6)
# ```
#
# - this is a compound object  ---> an object made of objects
#
# <u>**Class**</u>  ---> Object Design
#
# - is a design on how to create objects
# - `Int`, `Str`, `folium.folium.Map` are all objects ---> the pytohn team created the *classes for these objects*
# - `Int`, `Str`, `folium.folium.Map`  ---> are called object types
# - `class` keyword is used to create classes ---> to design an object

# %% [markdown]
# Create a program that generates random coordinates for an imaginary rectangle and the player has to guess coordinates and see if it is inside the rectangle or not
#
# <u>Description of the program</u>
#
# - The program displays a message to the user showing the coordinates of a rectangle.
# - The user should enter the coordinates of a point
#
# <u>**How many objects do we need for our program to run?**</u>
#
# 1. meesage ---> string ---> class that produces string instances (already designed)
# 2. coordinates ---> float (rectangle and points)
# 3. rectangle ---> new class ---> create object instance of that class
# 4. point ---> new class ---> create object instance of that class
#
# <u>**Development Steps (OOP design flow)**</u>
#
# 1. writing down the objects
# 2. write a class for each of that object
#     - what are the minimum requirements for that specific class to exist
# 3. writing methods/functions for each class
# 4. calling the classes (instantiate) and their methods

# %%
# the class

class Point:

    def __init__(self, x : int, y : int):
        self.x = x
        self.y = y

# Creating an object instance of type Point

point1 = Point(2,3)
type(point1)
# Out:
# __main__.Point

# %%
point1.x
# Out:
# 2

# %% [markdown]
# <u>**Point Class**</u>
#
# - `def __init__` ---> holds the parameters of the object I am creating
# - the `__init__` function is executed at object creation  ---> constructor
# - when we instantiate an object ---> it is of the type Point
# - we can create as many objects as we want with the type Point from the class Point
# - `__main__.Point`
#     - `__main__` is the name of the current script
#     - `Point` is the type of the object ---> the class
#     - `__main__` is file where the class is located
# - `self`
#     - variable that holds the object instance that is created by that class
#     - `x` will hold `2` and `self.x` will hold `x`
#     - `self.x` is called an instance variable
#     - `self.x` is the equivalent of `point1.x`

# %%
# Creating a method

class Point:

    def __init__(self, x : int, y : int):
        self.x = x
        self.y = y

    def falls_in_rectangle(self, lowleft : tuple, upright : tuple) -> bool:
        if lowleft[0] < self.x < upright[0] \
        and lowleft[1] < self.y < upright[1]:
            return True
        else:
            return False
        
    def distance_from_point(self, point : Point) -> float:
        return ((self.x - point.x)**2 + (self.y - point.y)**2) ** 0.5         

# intantiate the Point object        
point2 = Point(3,4)

# call method 1
print(point2.falls_in_rectangle((1,1), (7,9)))

# call method 2
point3 = Point(3,1)
point2.distance_from_point(point3)
# Out:
# True
# 3.0

# %% [markdown]
# <u>**Methods**</u>
#
# - using verbs to name the methods `falls_in_rectagle`
# - I need to pass the `self` in the method of that class

# %%
from __future__ import annotations # for type hints

class Point:

    def __init__(self, x : int, y : int):
        self.x = x
        self.y = y

    def falls_in_rectangle(self, rectangle : Rectangle) -> bool:
        if rectangle.lowleft.x < self.x < rectangle.upright.x \
        and rectangle.lowleft.y < self.y < rectangle.upright.y:
            return True
        else:
            return False
        
    def distance_from_point(self, point : Point) -> float:
        return ((self.x - point.x)**2 + (self.y - point.y)**2) ** 0.5  


class Rectangle:

    def __init__(self, lowleft : Point, upright : Point):
        self.lowleft = lowleft
        self.upright = upright


rectanglex = Rectangle(Point(5,6), Point(7,9))

pointx = Point(6,7)

pointx.falls_in_rectangle(rectanglex)
# Out:
# True

# %% [markdown]
# <u>**Rectangle Class**</u>
#
# - to create a rectangle we need two points ---> the object will be initialized with two point objects
# - `from __future__ import annotations` ---> for type hints
#
#
# <u>**Wrapping up**</u>
#
# 1. Create the Classes
# 2. Create the `__init__` of each class ---> attributes first
# 3. Create methods ---> based on what you need
#
# ---
#
# - with the rectangle and point classes defined we have the `Backend` ready
# - Building the interface for user interaction
#     - I will be building a *common line interface* which is a *text based interface*

# %%
from random import randint

# Step 1: create rectangle object
rectangle = Rectangle(
    lowleft = Point(randint(0,9), randint(0,9)),
    upright = Point(randint(0,9), randint(0,9))
)

print(
    "Rectangle Coordinates: ",
    rectangle.lowleft.x, ',',
    rectangle.lowleft.y, 'and',
    rectangle.upright.x, ',',
    rectangle.upright.y
)

# Step 2: take input from the user
user_point = Point(
    float(input('Guess X:')),
    float(input('Guess Y: '))
)

# Step 3: check if the user point is in the rectangle
print(
    'Your point was inside rectangle: ',
    user_point.falls_in_rectangle(rectangle)
)
# Out:
# Rectangle Coordinates:  7 , 3 and 3 , 7
# Your point was inside rectangle:  False

# %%
from __future__ import annotations # for type hints

class Point:

    def __init__(self, x : int, y : int):
        self.x = x
        self.y = y

    def falls_in_rectangle(self, rectangle : Rectangle) -> bool:
        if rectangle.point1.x < self.x < rectangle.point2.x \
        and rectangle.point1.y < self.y < rectangle.point2.y:
            return True
        else:
            return False
        
    def distance_from_point(self, point : Point) -> float:
        return ((self.x - point.x)**2 + (self.y - point.y)**2) ** 0.5  


class Rectangle:

    def __init__(self, point1 : Point, point2 : Point):
        self.point1 = point1
        self.point2 = point2

    def area(self):
        return  (self.point1.x - self.point2.x) * \
                (self.point1.y - self.point2.y)


from random import randint

# Step 1: create rectangle object
rectangle = Rectangle(
    point1 = Point(randint(0,9), randint(0,9)),
    point2 = Point(randint(0,9), randint(0,9))
)

print(
    "Rectangle Coordinates: ",
    rectangle.point1.x, ',',
    rectangle.point1.y, 'and',
    rectangle.point2.x, ',',
    rectangle.point2.y
)

# Step 2: take input from the user
user_point = Point(
    float(input('Guess X:')),
    float(input('Guess Y: '))
)
user_area = float(input('Guess rectangle area: '))


# Step 3: check if the user point is in the rectangle
print(
    'Your point was inside rectangle: ',
    user_point.falls_in_rectangle(rectangle)
)

print(
    f'Your area was off by: {rectangle.area() - user_area}'
)
# Out:
# Rectangle Coordinates:  9 , 0 and 8 , 6
# Your point was inside rectangle:  False
# Your area was off by: -561.0

# %% [markdown]
# <u>**Inheritance**</u>
